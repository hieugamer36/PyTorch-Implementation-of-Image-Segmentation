# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cd /content/gdrive/My Drive/ENet_CamVid/
# Out:
# /content/gdrive/My Drive/ENet_CamVid

# %%
 # !python main.py --train_img_root="./CamVid/train/" --train_label_root="./CamVid/trainannot/" --val_img_root="./CamVid/val/" --val_label_root="./CamVid/valannot/" --test_img_root="./CamVid/test/" --test_label_root="./CamVid/testannot/" --lr=0.0005 --batch_size=10 --epochs=300
# Out:
# lr :  0.0005
# Epochs :  300
# lr_decay_epochs :  100
# lr_decay :  0.1
# weight_decay :  0.0002
# batchsize :  10
# Number training :  367
# Number validation : 101
# Number testing :  233
# class_weights :  tensor([ 5.7920,  4.4403, 34.0217,  3.4469, 15.9119,  9.0202, 32.0138, 32.4789,
#         13.2071, 38.3877, 44.1345,  0.0000], device='cuda:0')
# 100% 37/37 [00:08<00:00,  4.22it/s, train_batch_loss=2.21]
# Epoch : 1/300 , val_loss =2.41, val_iou=0.08
# 100% 37/37 [00:08<00:00,  4.21it/s, train_batch_loss=1.97]
# Epoch : 2/300 , val_loss =2.04, val_iou=0.16
# 100% 37/37 [00:08<00:00,  4.22it/s, train_batch_loss=1.7]
# Epoch : 3/300 , val_loss =1.91, val_iou=0.20
# 100% 37/37 [00:08<00:00,  4.20it/s, train_batch_loss=1.57]
# Epoch : 4/300 , val_loss =1.75, val_iou=0.26
# 100% 37/37 [00:08<00:00,  4.19it/s, train_batch_loss=1.2]
# Epoch : 5/300 , val_loss =1.59, val_iou=0.30
# 100% 37/37 [00:08<00:00,  4.16it/s, train_batch_loss=1.03]
# ...

# %%
# !python data/camvid.py
